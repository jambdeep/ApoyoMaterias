# %% [markdown]
# <a href="https://colab.research.google.com/github/jambdeep/ApoyoMaterias/blob/main/EXTRA/EXTRA2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color='navy'>**EXAMEN EXTRAORDINARIO APIM 2023** </font>
# <font color='blue'> La entrega se realiza en los repositorios privados de cada alumno, creando una carpeta que deberá llamarse **EXAMEN EXTRAORDINARIO**

# %% [markdown]
# ## <font color='darkviolet'>**Ejercicio 1 (2 puntos)**
#
# ### <font color='orange'>**Realizar una función en python que permita dar como argumento de entrada la imagen almacenada en formato de la librería Pillow y detecte si está en color, la debe convertir a escalas de grises y mostrarla en pantalla**</font>

# %% [markdown]
# Ejemplo de imagen
#
# ![Esqueleto](https://github.com/jambdeep/ApoyoMaterias/blob/main/EXTRA/esqueleto.jpg?raw=true)

# %%
#Ejemplo de funcionamiento
convert_gray(imagen)

# %% [markdown]
# ## <font color='darkviolet'>**Ejercicio 2 (5 puntos)**
#
# ### <font color='orange'>**Realizar el procesamiento de imágenes en cada celda para obtener los resultados mostrados*</font>

# %%
# Leer y mostrar la imagen (XRAY02.jpg) (1 punto)
# Out:
# (<matplotlib.image.AxesImage at 0x7f2c58444a30>,
#  Text(0.5, 1.0, 'X-ray'),
#  (-0.5, 255.5, 402.5, -0.5))

# %%
#Obtener la gráfica mostrada (1 punto)

# %%
#Obtener la máscara mostrada (1 punto)
# Out:
# (<matplotlib.image.AxesImage at 0x7f2c83aef6a0>, Text(0.5, 1.0, 'Máscara'))

# %%
#Obtener la imagen procesada mostrada (1 punto)
# Out:
# (<matplotlib.image.AxesImage at 0x7f2c56e3df90>,
#  Text(0.5, 1.0, 'Imagen procesada'))

# %%
#Obtener la imagen procesada mostrada (1 punto)
# Out:
# (<matplotlib.image.AxesImage at 0x7f2c570c8280>,
#  Text(0.5, 1.0, 'Imagen Procesada'))

# %% [markdown]
# ## <font color='darkviolet'>**Ejercicio 3 (3 puntos)**
#
# ### <font color='orange'>**Realizar el procesamiento de imágenes en cada celda para obtener los resultados mostrados*</font>

# %%
# Mostrar la siguiente imagen (1 punto)
# Out:
# (-0.5, 1279.5, 719.5, -0.5)

# %%
# Mediante procesamiento de imágenes visto en clase convertir la imagen anterior a fondo blanco con todos los círculos azules (2 puntos)
